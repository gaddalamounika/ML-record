# %%
import pandas as pd
df=pd.read_csv('Car_sales.csv')
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.shape
# Out:
# (157, 15)

# %%
df.shape[0]
# Out:
# 157

# %%
df.shape[1]
# Out:
# 15

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool

# %%
duplicates=df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
df_clean=df.drop_duplicates()

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df.isnull()
# Out:
#      Manufacturer  Model  Sales in thousands  4-year resale value  \
# 0           False  False               False                False
# 1           False  False               False                False
# 2           False  False               False                False
# 3           False  False               False                False
# 4           False  False               False                False
# ..            ...    ...                 ...                  ...
# 152         False  False               False                False
# 153         False  False               False                False
# 154         False  False               False                False
# 155         False  False               False                False
# 156         False  False               False                False
#
#      Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0           False               False        False       False      False
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
mmv=df.isnull().sum().idxmax()

# %%
categorical_cols = df.select_dtypes(include='object').columns
df = df.dropna(subset=categorical_cols)

# %% [markdown]
# mmv

# %%
print(categorical_cols)
# Out:
# Index(['Manufacturer', 'Model', '4-year resale value', 'Vehicle type',
#        'Price in thousands', 'Engine size', 'Horsepower', 'Wheelbase', 'Width',
#        'Length', 'Curb weight', 'Fuel capacity', 'Fuel efficiency',
#        'Latest Launch'],
#       dtype='object')

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
df_sorted = df.sort_values(by='Price in thousands', ascending=False)
print("Most expensive:", df_sorted.head(1))
print("Least expensive:", df_sorted.tail(1))
# Out:
# Most expensive:      Manufacturer              Model  Sales in thousands 4-year resale value  \
# 62  Hyundai        Accent                         41.184                5.86
#
#    Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 62    Passenger              9.699         1.5         92      96.1  65.7
#
#    Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 62  166.7        2.24          11.9              31      9-Oct-14
# Least expensive:     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 2  Acura          CL                             14.114              18.225
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 2    Passenger                  .         3.2        225     106.9  70.6
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 2    192        3.47          17.2              26      1-Apr-14

# %%
def find_min_max(column):
    return column.min(), column.max()

# %%
print(find_min_max(df['Horsepower']))
print(find_min_max(df['Length']))
print(find_min_max(df['Fuel efficiency']))
# Out:
# ('.', '92')
# ('.', '224.5')
# ('.', '45')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cols=['Price in thousands','Sales in thousands','Horsepower','Fuel efficiency']
for col in cols:
    sns.histplot(x=col,data=df)
    plt.show()

# %%
print(df.columns)
# Out:
# Index(['Manufacturer', 'Model', 'Sales in thousands', '4-year resale value',
#        'Vehicle type', 'Price in thousands', 'Engine size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb weight', 'Fuel capacity',
#        'Fuel efficiency', 'Latest Launch'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Optional: Convert to numeric if needed (to avoid future errors)
df['Price in thousands'] = pd.to_numeric(df['Price in thousands'], errors='coerce')
df['Horsepower'] = pd.to_numeric(df['Horsepower'], errors='coerce')
df['Fuel efficiency'] = pd.to_numeric(df['Fuel efficiency'], errors='coerce')
df['Sales in thousands'] = pd.to_numeric(df['Sales in thousands'], errors='coerce')

# Plot histogram
df[['Price in thousands', 'Sales in thousands', 'Horsepower', 'Fuel efficiency']].hist(figsize=(10,8))
plt.show()

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
print(num_cols)
# Out:
# Index(['Sales in thousands', 'Price in thousands', 'Horsepower',
#        'Fuel efficiency'],
#       dtype='object')

# %%
print(df['Price in thousands'].corr(df['Sales in thousands']))
# Out:
# -0.3047344541294122

# %%
import seaborn as sns
sns.scatterplot(x='Price in thousands',y='Sales in thousands',data=df)
plt.show()

# %%
#import matplotlib.pyplot as plt
sns.pairplot(df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='Manufacturer',y='Sales in thousands',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in ['Price in thousands', 'Horsepower', 'Fuel efficiency']:
    sns.boxplot(x='Manufacturer', y=col, data=df)
    plt.show()

# %%
y = df['Sales in thousands']
X = df.drop(columns=['Sales in thousands'])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in X.select_dtypes(include='object').columns:
    X[col] = le.fit_transform(X[col])
    print(f"Encoded column: {col}")

# %%
X=pd.get_dummies(X,columns=['Vehicle type'])

# %%
X
# Out:
#      Manufacturer  Model  4-year resale value  Price in thousands  \
# 0               0     79                   53                  59
# 1               0    143                   70                 102
# 2               0     25                   63                   0
# 3               0    115                   87                 130
# 4               1      8                   78                  77
# ..            ...    ...                  ...                 ...
# 152            29    148                    0                  80
# 153            29    125                    0                  98
# 154            29    149                    0                 103
# 155            29     24                    0                 136
# 156            29    126                    0                 119
#
#      Engine size  Horsepower  Wheelbase  Width  Length  Curb weight  \
# 0              4          17          5      9      15           18
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

print("After scaling:")
print(pd.DataFrame(X_train[num_cols]).describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-64b97d56d971> in <module>
#       2 scaler=StandardScaler()
#       3 scaler = StandardScaler()
# ----> 4 X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
#       5 X_test[num_cols] = scaler.transform(X_test[num_cols])
#       6
#
# NameError: name 'num_cols' is not defined
