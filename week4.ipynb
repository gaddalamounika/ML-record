# %%
import pandas as pd
df=pd.read_csv("Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
df.shape
# Out:
# (545, 13)

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
X=df.drop(columns='price')
y=df['price']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x=df['bedrooms'],y=df['price'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure
sns.scatterplot(x=df["area"],y=df["price"])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

for col in df.select_dtypes(exclude='number').columns:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[col])
  
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
X=pd.get_dummies(df,drop_first=True)

# %%
X
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

for col in df.select_dtypes(exclude='number').columns:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[col])
  
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Select only numerical columns
#num_cols = ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Fit and transform
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
print("Training data shape:", X_train.shape, y_train.shape)
print("Testing data shape:", X_test.shape, y_test.shape)
# Out:
# Training data shape: (381, 13) (381,)
# Testing data shape: (164, 13) (164,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
print("intercept",model.intercept_)
print("coeffient:",model.coef_)
# Out:
# intercept 9.313225746154785e-10
# coeffient: [ 1.00000000e+00 -1.55203494e-15 -4.83909398e-12 -1.32161866e-11
#  -6.50319232e-12  2.30495857e-12 -7.30878598e-11  4.13845557e-11
#  -7.42761501e-11 -3.60875652e-11  2.69362153e-11  4.85817152e-11
#   3.06117147e-11]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train, y_train)
print("intercept:", model.intercept_)
print("coef:", model.coef_)
# Out:
# intercept: 9.313225746154785e-10
# coef: [ 1.00000000e+00 -1.55203494e-15 -4.83909398e-12 -1.32161866e-11
#  -6.50319232e-12  2.30495857e-12 -7.30878598e-11  4.13845557e-11
#  -7.42761501e-11 -3.60875652e-11  2.69362153e-11  4.85817152e-11
#   3.06117147e-11]

# %%
# Step 1: Predict on the training set
y_train_pred = model.predict(X_train)

# Step 2: Calculate the error
error = y_train_pred - y_train

# Step 3: Display the first few values
print("Predicted Prices:", y_train_pred[:5])
print("Actual Prices:", y_train[:5].values)
print("Error (y_pred - y_train):", error[:5].values)
# Out:
# Predicted Prices: [3760474.97796363 2923291.90715042 6646222.44721044 3302533.32630785
#  6264504.93742689]
# Actual Prices: [4235000 2940000 8190000 2961000 6195000]
# Error (y_pred - y_train): [ -474525.02203637   -16708.09284958 -1543777.55278956   341533.32630785
#     69504.93742689]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Predict on training set
y_train_pred = model.predict(X_train)

# Step 2: Calculate residuals
residuals = y_train_pred - y_train

# Step 3: Create Residual Plot using Seaborn
plt.figure(figsize=(8, 5))  # Set figure size
sns.scatterplot(x=y_train_pred, y=residuals, color='blue', alpha=0.6)

# Step 4: Add a horizontal reference line at y=0
plt.axhline(y=0, color='red', linestyle='--')

# Step 5: Customize labels and title
plt.xlabel("Predicted Prices (y_pred)")
plt.ylabel("Residuals (Error)")
plt.title("Residual Plot (Seaborn)")

# Step 6: Show the plot
plt.show()

# %%
# Step 1: Predict on the training set
y_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Predict on training set
y_train_pred = model.predict(X_train)

# Step 2: Calculate MSE
mse = mean_squared_error(y_train, y_train_pred)

# Step 3: Calculate R² Score
r2 = r2_score(y_train, y_train_pred)

# Step 4: Print results
print("Mean Squared Error (MSE):", mse)
print("R Squared Value (R² Score):", r2)
# Out:
# Mean Squared Error (MSE): 1138996150052.1553
# R Squared Value (R² Score): 0.6845117266621765

# %%
y_test_pred = model.predict(X_test)
test_errors = y_test_pred - y_test

plt.scatter(y_test_pred, test_errors)
plt.xlabel('Predicted Values')
plt.ylabel('Residuals (Errors)')
plt.title('Residual Plot - Test')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# For Train Set
mse_train = mean_squared_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)

# For Test Set
mse_test = mean_squared_error(y_test, y_test_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f"Train MSE: {mse_train:.2f}")
print(f"Train R²: {r2_train:.2f}")
print(f"Test MSE: {mse_test:.2f}")
print(f"Test R²: {r2_test:.2f}")
# Out:
# Train MSE: 1138996150052.16
# Train R²: 0.68
# Test MSE: 1090852329168.35
# Test R²: 0.66

# %%
import statsmodels.api as sm

# Add a constant to X_train
X_train_sm = sm.add_constant(X_train)

# Now build the model
model = sm.OLS(y_train, X_train_sm).fit()

# Print Adjusted R²
print("Adjusted R²:", model.rsquared_adj)
# Out:
# Adjusted R²: 0.6733363927292291

# %%
import seaborn as sns
y_test_pred=model.predict(X_test)
err=y_test_pred-y_test
#print(residuals)
plt.figure(figsize=(10,4))
sns.scatterplot(x=y_test_pred,y=err,color='blue')
# Out:
# <Axes: ylabel='price'>
